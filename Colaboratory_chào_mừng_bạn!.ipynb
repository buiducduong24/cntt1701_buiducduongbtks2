# %% [markdown]
# <a href="https://colab.research.google.com/github/buiducduong24/cntt1701_buiducduongbtks2/blob/main/Colaboratory_ch%C3%A0o_m%E1%BB%ABng_b%E1%BA%A1n!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Định nghĩa đường dẫn đến file
file_path = "/content/drive/MyDrive/CNTT1701_buiducduongbtks2.xlsx"

# Đọc file Excel
df = pd.read_excel(file_path)

# Hiển thị nội dung file
print(df)
# Out:
#   Mã sinh viên            Ngành học  GPA  Số tín chỉ tích lũy  \
# 0        SV001                 CNTT  2.5                   60
# 1        SV002              Kinh tế  3.2                   90
# 2        SV003  Quản trị kinh doanh  3.8                  120
# 3        SV004                 CNTT  2.9                   75
# 4        SV005              Kinh tế  3.5                  100
# 5        SV006  Quản trị kinh doanh  3.1                  110
#
#    Số giờ tự học mỗi tuần
# 0                       5
# 1                      10
# 2                      15
# 3                       8
# 4                      12
# 5                       9

# %%
import pandas as pd

# Đọc file Excel
file_path = "/content/drive/MyDrive/CNTT1701_buiducduongbtks2.xlsx"
df = pd.read_excel(file_path)

# In ra dữ liệu gốc
print("Dữ liệu gốc:")
print(df)

# Kiểm tra và xử lý dữ liệu thiếu
print("\nKiểm tra dữ liệu thiếu:")
print(df.isnull().sum())
df = df.dropna()  # Xóa các dòng có giá trị thiếu

# Kiểm tra và sửa lỗi định dạng dữ liệu
print("\nKiểm tra kiểu dữ liệu:")
print(df.dtypes)

# Define columns to convert to numeric
numeric_cols = ["Mã sinh viên","Ngành học","GPA","Số tín chỉ tích lũy","Số giờ tự học mỗi tuần"]

"Mã sinh viên","Ngành học","GPA","Số tín chỉ tích lũy","Số giờ tự học mỗi tuần"
# In ra dữ liệu sau khi làm sạch
print("\nDữ liệu sau khi làm sạch:")
print(df)

# Lưu bộ dữ liệu mới vào file Excel
cleaned_file_path = "/content/drive/MyDrive/CNTT1701_buiducduongbtks2.xlsx"
df.to_excel(cleaned_file_path, index=False)

print(f"Dữ liệu sau khi làm sạch đã được lưu vào {cleaned_file_path}")
# Out:
# Dữ liệu gốc:
#   Mã sinh viên            Ngành học  GPA  Số tín chỉ tích lũy  \
# 0        SV001                 CNTT  2.5                   60
# 1        SV002              Kinh tế  3.2                   90
# 2        SV003  Quản trị kinh doanh  3.8                  120
# 3        SV004                 CNTT  2.9                   75
# 4        SV005              Kinh tế  3.5                  100
# 5        SV006  Quản trị kinh doanh  3.1                  110
#
#    Số giờ tự học mỗi tuần
# 0                       5
# 1                      10
# 2                      15
# 3                       8
# 4                      12
# 5                       9
#
# Kiểm tra dữ liệu thiếu:
# Mã sinh viên              0
# Ngành học                 0
# GPA                       0
# Số tín chỉ tích lũy       0
# Số giờ tự học mỗi tuần    0
# dtype: int64
#
# Kiểm tra kiểu dữ liệu:
# Mã sinh viên               object
# Ngành học                  object
# GPA                       float64
# ...

# %%
print("\nCác chỉ số thống kê cơ bản:")
print(df.describe())

# Bổ sung các chỉ số thống kê khác
if "Điểm" in df.columns:
    print("\nCác chỉ số thống kê mở rộng về cột 'Điểm':")
    print(f"Trung bình: {df['Điểm'].mean()}")
    print(f"Trung vị: {df['Điểm'].median()}")
    print(f"Phương sai: {df['Điểm'].var()}")
    print(f"Độ lệch chuẩn: {df['Điểm'].std()}")
    print(f"Giá trị nhỏ nhất: {df['Điểm'].min()}")
    print(f"Giá trị lớn nhất: {df['Điểm'].max()}")

# Vẽ biểu đồ phân phối của một cột số liệu quan trọng (giả sử có cột 'Điểm')
if "Điểm" in df.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df["Điểm"], bins=10, kde=True)
    plt.title("Phân phối điểm số")
    plt.xlabel("Điểm")
    plt.ylabel("Tần suất")
    plt.show()
else:
    print("Không tìm thấy cột 'Điểm' trong dữ liệu.")

# Vẽ biểu đồ cột thể hiện số lượng sinh viên theo một cột danh mục (giả sử 'Ngành học')
if "Ngành học" in df.columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(y=df["Ngành học"], order=df["Ngành học"].value_counts().index)
    plt.title("Số lượng sinh viên theo ngành học")
    plt.xlabel("Số lượng")
    plt.ylabel("Ngành học")
    plt.show()
else:
    print("Không tìm thấy cột 'Ngành học' trong dữ liệu.")
# Out:
# Các chỉ số thống kê cơ bản:
#             GPA  Số tín chỉ tích lũy  Số giờ tự học mỗi tuần
# count  6.000000             6.000000                6.000000
# mean   3.166667            92.500000                9.833333
# std    0.454606            22.304708                3.430258
# min    2.500000            60.000000                5.000000
# 25%    2.950000            78.750000                8.250000
# 50%    3.150000            95.000000                9.500000
# 75%    3.425000           107.500000               11.500000
# max    3.800000           120.000000               15.000000
# Không tìm thấy cột 'Điểm' trong dữ liệu.

# %%
from sklearn.model_selection import train_test_split


# Xử lý dữ liệu đầu vào
feature_columns = ["Số tín chỉ tích lũy", "Số giờ tự học mỗi tuần"]
X = df[feature_columns]
y = df["GPA"]

# Chia dữ liệu
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(X.head())
print(y.head())


# Hàm đánh giá mô hình
def evaluate_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return {
        "MAE": mean_absolute_error(y_test, y_pred),
        "MSE": mean_squared_error(y_test, y_pred),
        "RMSE": mean_squared_error(y_test, y_pred) ** 0.5,

        "R2": r2_score(y_test, y_pred)
    }

# Huấn luyện và đánh giá các mô hình
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42)
}

results = {name: evaluate_model(model, X_train, X_test, y_train, y_test) for name, model in models.items()}

# In kết quả đánh giá
print("\nSo sánh kết quả mô hình:")
results_df = pd.DataFrame(results).T
print(results_df)

# Biểu đồ so sánh
results_df.plot(kind='bar', figsize=(10, 5))
plt.title("So sánh độ chính xác của các mô hình")
plt.xlabel("Mô hình")
plt.ylabel("Giá trị")
plt.xticks(rotation=45)
plt.show()
# Out:
#    Số tín chỉ tích lũy  Số giờ tự học mỗi tuần
# 0                   60                       5
# 1                   90                      10
# 2                  120                      15
# 3                   75                       8
# 4                  100                      12
# 0    2.5
# 1    3.2
# 2    3.8
# 3    2.9
# 4    3.5
# Name: GPA, dtype: float64
#
# So sánh kết quả mô hình:
#                         MAE       MSE      RMSE        R2
# Linear Regression  0.027649  0.001013  0.031820  0.991735
# Decision Tree      0.350000  0.125000  0.353553 -0.020408
# Random Forest      0.306000  0.133237  0.365016 -0.087649
